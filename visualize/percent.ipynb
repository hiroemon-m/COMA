# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cbook as cbook

# %%
attr_auc_baseline = []
attr_nll_baseline = []
edge_auc_baseline = []
edge_nll_baseline = []




attr_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/persona=5/proposed_attr_auc.npy"
attr_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/persona=5/proposed_attr_nll.npy"
edge_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/persona=5/proposed_edge_auc.npy"
edge_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/persona=5/proposed_edge_nll.npy"

attr_auc_baseline.append(np.load(attr_auc_path))
attr_nll_baseline.append(np.load(attr_nll_path))
edge_auc_baseline.append(np.load(edge_auc_path))
edge_nll_baseline.append(np.load(edge_nll_path))


attr_mean_baseline = np.mean(attr_auc_baseline,axis=1)
attr_max_baseline = np.max(attr_auc_baseline,axis=1)
attr_min_baseline = np.min(attr_auc_baseline,axis=1)

attr_mean_nll_baseline = np.mean(attr_nll_baseline,axis=1)
attr_max_nll_baseline = np.max(attr_nll_baseline,axis=1)
attr_min_nll_baseline = np.min(attr_nll_baseline,axis=1)

edge_mean_baseline = np.mean(edge_auc_baseline,axis=1)
edge_max_baseline = np.max(edge_auc_baseline,axis=1)
edge_min_baseline = np.min(edge_auc_baseline,axis=1)

edge_mean_nll_baseline = np.mean(edge_nll_baseline,axis=1)
edge_max_nll_baseline = np.max(edge_nll_baseline,axis=1)
edge_min_nll_baseline = np.min(edge_nll_baseline,axis=1)

# %%
attr_auc_time =[]
attr_nll_time = []
edge_auc_time = []
edge_nll_time = []
plist=[5,15,30,50,75]
for percent in [5,15,30,50,75]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    for i in range(15):

        path = "/Users/matsumoto-hirotomo/study/experiment_data/NIPS/incomplete/t=4/attr/percent={}/attempt={}".format(percent,i)
        attr_auc_path = path+"/proposed_attr_auc.npy".format(i)
        attr_nll_path = path+"/proposed_attr_nll.npy".format(i)
        edge_auc_path = path+"/proposed_edge_auc.npy".format(i)
        edge_nll_path = path+"/proposed_edge_nll.npy".format(i)

        attr_auc.append(np.load(attr_auc_path))
        attr_nll.append(np.load(attr_nll_path))
        edge_auc.append(np.load(edge_auc_path))
        edge_nll.append(np.load(edge_nll_path))


    #attr_auc_time.append()
    #attr_nll_time = []
    #edge_auc_time = []
    #edge_nll_time = []
    #ある時刻での欠損の位置を変えた時のそれぞれの値
    time_attr_auc = np.mean(attr_auc,axis=1)
    time_edge_auc = np.mean(edge_auc,axis=1)
    time_attr_nll = np.mean(attr_nll,axis=1)
    time_edge_nll = np.mean(edge_nll,axis=1)

    #auc
    attr_auc_mean = np.mean(time_attr_auc,axis=0)
    attr_auc_max = np.max(time_attr_auc,axis=0)
    attr_auc_min = np.min(time_attr_auc,axis=0)
    edge_auc_mean = np.mean(time_edge_auc,axis=0)
    edge_auc_max = np.max(time_edge_auc,axis=0)
    edge_auc_min = np.min(time_edge_auc,axis=0)

    attr_auc_time.append([attr_auc_mean,attr_auc_min,attr_auc_max])
    edge_auc_time.append([edge_auc_mean,edge_auc_min,edge_auc_max])

    #nll
    attr_nll_mean = np.mean(time_attr_nll,axis=0)
    attr_nll_max = np.max(time_attr_nll,axis=0)
    attr_nll_min = np.min(time_attr_nll,axis=0)
    edge_nll_mean = np.mean(time_edge_nll,axis=0)
    edge_nll_max = np.max(time_edge_nll,axis=0)
    edge_nll_min = np.min(time_edge_nll,axis=0)

    attr_nll_time.append([attr_nll_mean,attr_nll_min,attr_nll_max])
    edge_nll_time.append([edge_nll_mean,edge_nll_min,edge_nll_max])

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 20))


t = [1,2,3,4,5]
colorli = ['red','orange','green','sienna','teal']
titleli = ['edge auc','attr auc','edge nll','attr nll']

for k in range(len(plist)):
    print(edge_auc_time)
    print(edge_nll_time[0][0])
  

#edge auc
#平均
   
    axes[0,0].plot(t, edge_auc_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[0,0].fill_between(t, edge_auc_time[k][1], edge_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[0,1].plot(t, attr_auc_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[0,1].fill_between(t, attr_auc_time[k][1], attr_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[1,0].plot(t, edge_nll_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[1,0].fill_between(t, edge_nll_time[k][1], edge_nll_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション

   


    axes[1,1].plot(t, attr_nll_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[1,1].fill_between(t, attr_nll_time[k][1], attr_nll_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション

   

    axes[0,0].set_xticks([1,2,3,4,5])  
    axes[0,1].set_xticks([1,2,3,4,5])    
    axes[1,0].set_xticks([1,2,3,4,5])
    axes[1,1].set_xticks([1,2,3,4,5])
axes[0,0].plot(t, edge_mean_baseline[0][:], lw=2, label='REINFORCE', color='blue')
axes[0,0].fill_between(t, edge_max_baseline[0][:], edge_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0,1].plot(t, attr_mean_baseline[0][:], lw=2, label='REINFORCE', color='blue')
axes[0,1].fill_between(t, attr_max_baseline[0][:], attr_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1,0].plot(t, edge_mean_nll_baseline[0][:], lw=2, label='REINFORCE', color='blue')
axes[1,0].fill_between(t, edge_max_nll_baseline[0][:], edge_min_nll_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1,1].plot(t, attr_mean_nll_baseline[0][:], lw=2, label='REINFORCE', color='blue')
axes[1,1].fill_between(t, attr_max_nll_baseline[0][:], attr_min_nll_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0,0].set_title(titleli[0])
axes[0,0].legend(loc='upper left')
axes[0,0].set_xlabel('time')
axes[0,0].set_ylabel('accuracy')
axes[0,1].set_title(titleli[1])
axes[0,1].legend(loc='upper left')
axes[0,1].set_xlabel('time')
axes[0,1].set_ylabel('accuracy')
axes[1,0].set_title(titleli[2])
axes[1,0].legend(loc='upper left')
axes[1,0].set_xlabel('time')
axes[1,0].set_ylabel('nll')
axes[1,1].set_title(titleli[3])
axes[1,1].set_title(r'attr nll ')
axes[1,1].legend(loc='upper left')
axes[1,1].set_xlabel('time')
axes[1,1].set_ylabel('nll')
# Out:
# [[array([0.92697039, 0.9367664 , 0.94627337, 0.94389904, 0.83450379]), array([0.90439822, 0.91175929, 0.90651677, 0.91157004, 0.78711656]), array([0.9366817 , 0.9510353 , 0.9597815 , 0.96083256, 0.85634947])], [array([0.88108816, 0.89980183, 0.93107275, 0.9106553 , 0.84340676]), array([0.83649743, 0.84898409, 0.87293699, 0.84253942, 0.80094025]), array([0.91801232, 0.92781738, 0.96315295, 0.96343692, 0.87975349])], [array([0.85045017, 0.86424708, 0.85885247, 0.83452396, 0.78753801]), array([0.80646882, 0.83371763, 0.8028811 , 0.75952226, 0.75485018]), array([0.87296334, 0.93346911, 0.90458079, 0.87935065, 0.83763448])], [array([0.78127   , 0.86510296, 0.77146528, 0.75694303, 0.72275555]), array([0.73404616, 0.81616478, 0.74731453, 0.71262639, 0.68042811]), array([0.82574435, 0.89903501, 0.79799543, 0.78305659, 0.81113408])], [array([0.82582436, 0.85208944, 0.87160476, 0.86603942, 0.79859229]), array([0.62275725, 0.68634953, 0.69020579, 0.67365492, 0.67686939]), array([0.943119  , 0.9
# ...

# %%
attr_auc_time =[]
attr_nll_time = []
edge_auc_time = []
edge_nll_time = []
plist=[5,15,30,50,75]
for percent in [5,15,30,50,75]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    for i in range(15):

        path = "/Users/matsumoto-hirotomo/study/experiment_data/NIPS/incomplete/t=4/edge/percent={}/attempt={}".format(percent,i)
        attr_auc_path = path+"/proposed_attr_auc.npy".format(i)
        attr_nll_path = path+"/proposed_attr_nll.npy".format(i)
        edge_auc_path = path+"/proposed_edge_auc.npy".format(i)
        edge_nll_path = path+"/proposed_edge_nll.npy".format(i)

        attr_auc.append(np.load(attr_auc_path))
        attr_nll.append(np.load(attr_nll_path))
        edge_auc.append(np.load(edge_auc_path))
        edge_nll.append(np.load(edge_nll_path))


    #attr_auc_time.append()
    #attr_nll_time = []
    #edge_auc_time = []
    #edge_nll_time = []
    #ある時刻での欠損の位置を変えた時のそれぞれの値
    time_attr_auc = np.mean(attr_auc,axis=1)
    time_edge_auc = np.mean(edge_auc,axis=1)
    time_attr_nll = np.mean(attr_nll,axis=1)
    time_edge_nll = np.mean(edge_nll,axis=1)

    #auc
    attr_auc_mean = np.mean(time_attr_auc,axis=0)
    attr_auc_max = np.max(time_attr_auc,axis=0)
    attr_auc_min = np.min(time_attr_auc,axis=0)
    edge_auc_mean = np.mean(time_edge_auc,axis=0)
    edge_auc_max = np.max(time_edge_auc,axis=0)
    edge_auc_min = np.min(time_edge_auc,axis=0)

    attr_auc_time.append([attr_auc_mean,attr_auc_min,attr_auc_max])
    edge_auc_time.append([edge_auc_mean,edge_auc_min,edge_auc_max])

    #nll
    attr_nll_mean = np.mean(time_attr_nll,axis=0)
    attr_nll_max = np.max(time_attr_nll,axis=0)
    attr_nll_min = np.min(time_attr_nll,axis=0)
    edge_nll_mean = np.mean(time_edge_nll,axis=0)
    edge_nll_max = np.max(time_edge_nll,axis=0)
    edge_nll_min = np.min(time_edge_nll,axis=0)

    attr_nll_time.append([attr_nll_mean,attr_nll_min,attr_nll_max])
    edge_nll_time.append([edge_nll_mean,edge_nll_min,edge_nll_max])

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 20))


t = [1,2,3,4,5]
colorli = ['red','orange','green','sienna','teal']
titleli = ['edge auc','attr auc','edge nll','attr nll']

for k in range(len(plist)):
    print(edge_auc_time)
    print(edge_nll_time[0][0])
  

#edge auc
#平均
   
    axes[0,0].plot(t, edge_auc_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[0,0].fill_between(t, edge_auc_time[k][1], edge_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[0,1].plot(t, attr_auc_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[0,1].fill_between(t, attr_auc_time[k][1], attr_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[1,0].plot(t, edge_nll_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[1,0].fill_between(t, edge_nll_time[k][1], edge_nll_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション

   


    axes[1,1].plot(t, attr_nll_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[1,1].fill_between(t, attr_nll_time[k][1], attr_nll_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション

   

    axes[0,0].set_xticks([1,2,3,4,5])  
    axes[0,1].set_xticks([1,2,3,4,5])    
    axes[1,0].set_xticks([1,2,3,4,5])
    axes[1,1].set_xticks([1,2,3,4,5])

axes[0,0].plot(t, edge_mean_baseline[0][:], lw=2, label='complete data', color='blue')
axes[0,0].fill_between(t, edge_max_baseline[0][:], edge_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0,1].plot(t, attr_mean_baseline[0][:], lw=2, label='complete data', color='blue')
axes[0,1].fill_between(t, attr_max_baseline[0][:], attr_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1,0].plot(t, edge_mean_nll_baseline[0][:], lw=2, label='complete data', color='blue')
axes[1,0].fill_between(t, edge_max_nll_baseline[0][:], edge_min_nll_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1,1].plot(t, attr_mean_nll_baseline[0][:], lw=2, label='complete data', color='blue')
axes[1,1].fill_between(t, attr_max_nll_baseline[0][:], attr_min_nll_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0,0].set_title(titleli[0])
axes[0,0].legend(loc='upper left')
axes[0,0].set_xlabel('time')
axes[0,0].set_ylabel('accuracy')
axes[0,1].set_title(titleli[1])
axes[0,1].legend(loc='upper left')
axes[0,1].set_xlabel('time')
axes[0,1].set_ylabel('accuracy')
axes[1,0].set_title(titleli[2])
axes[1,0].legend(loc='upper left')
axes[1,0].set_xlabel('time')
axes[1,0].set_ylabel('nll')
axes[1,1].set_title(titleli[3])
axes[1,1].set_title(r'attr nll ')
axes[1,1].legend(loc='upper left')
axes[1,1].set_xlabel('time')
axes[1,1].set_ylabel('nll')
# Out:
# [[array([0.94211118, 0.94588813, 0.9525376 , 0.95565005, 0.84016575]), array([0.9419067 , 0.94366211, 0.94979675, 0.95350881, 0.83538499]), array([0.94268257, 0.94980846, 0.95560976, 0.95821429, 0.84670357])], [array([0.94220008, 0.94615273, 0.95313592, 0.95578309, 0.8406378 ]), array([0.94180972, 0.94201581, 0.95015498, 0.9534833 , 0.83118387]), array([0.94265833, 0.94902531, 0.95722815, 0.9579128 , 0.84396061])], [array([0.94225342, 0.94555628, 0.95264905, 0.95534818, 0.84067877]), array([0.94168849, 0.94103627, 0.94961382, 0.95217764, 0.83637192]), array([0.94317961, 0.94913684, 0.95757876, 0.9605821 , 0.84643683])], [array([0.9420449 , 0.94625618, 0.95234112, 0.95506192, 0.84098337]), array([0.94147027, 0.94395306, 0.94929624, 0.95331633, 0.83654086]), array([0.9426462 , 0.94999758, 0.95504827, 0.9569179 , 0.84536432])], [array([0.94212896, 0.9465123 , 0.9530426 , 0.95624629, 0.83967502]), array([0.94173698, 0.94267287, 0.95003303, 0.95394017, 0.83502823]), array([0.94297352, 0.9
# ...

# %% [markdown]
# DBLP

# %%
attr_auc_baseline = []
attr_nll_baseline = []
edge_auc_baseline = []
edge_nll_baseline = []




attr_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLPP/persona=5/proposed_attr_auc.npy"
attr_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLPP/persona=5/proposed_attr_nll.npy"
edge_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLPP/persona=5/proposed_edge_auc.npy"
edge_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLPP/persona=5/proposed_edge_nll.npy"

attr_auc_baseline.append(np.load(attr_auc_path))
attr_nll_baseline.append(np.load(attr_nll_path))
edge_auc_baseline.append(np.load(edge_auc_path))
edge_nll_baseline.append(np.load(edge_nll_path))


attr_mean_baseline = np.mean(attr_auc_baseline,axis=1)
attr_max_baseline = np.max(attr_auc_baseline,axis=1)
attr_min_baseline = np.min(attr_auc_baseline,axis=1)

attr_mean_nll_baseline = np.mean(attr_nll_baseline,axis=1)
attr_max_nll_baseline = np.max(attr_nll_baseline,axis=1)
attr_min_nll_baseline = np.min(attr_nll_baseline,axis=1)

edge_mean_baseline = np.mean(edge_auc_baseline,axis=1)
edge_max_baseline = np.max(edge_auc_baseline,axis=1)
edge_min_baseline = np.min(edge_auc_baseline,axis=1)

edge_mean_nll_baseline = np.mean(edge_nll_baseline,axis=1)
edge_max_nll_baseline = np.max(edge_nll_baseline,axis=1)
edge_min_nll_baseline = np.min(edge_nll_baseline,axis=1)

# %%
attr_auc_time =[]
attr_nll_time = []
edge_auc_time = []
edge_nll_time = []
plist=[5,15,30,50,75]
for percent in [5,15,30,50,75]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    for i in range(11,14):

        path = "/Users/matsumoto-hirotomo/study/experiment_data/DBLP/incomplete/t=4/attr/percent={}/attempt={}".format(percent,i)
        attr_auc_path = path+"/proposed_attr_auc.npy".format(i)
        attr_nll_path = path+"/proposed_attr_nll.npy".format(i)
        edge_auc_path = path+"/proposed_edge_auc.npy".format(i)
        edge_nll_path = path+"/proposed_edge_nll.npy".format(i)

        attr_auc.append(np.load(attr_auc_path))
        attr_nll.append(np.load(attr_nll_path))
        edge_auc.append(np.load(edge_auc_path))
        edge_nll.append(np.load(edge_nll_path))


    #attr_auc_time.append()
    #attr_nll_time = []
    #edge_auc_time = []
    #edge_nll_time = []
    #ある時刻での欠損の位置を変えた時のそれぞれの値
    time_attr_auc = np.mean(attr_auc,axis=1)
    time_edge_auc = np.mean(edge_auc,axis=1)
    time_attr_nll = np.mean(attr_nll,axis=1)
    time_edge_nll = np.mean(edge_nll,axis=1)

    #auc
    attr_auc_mean = np.mean(time_attr_auc,axis=0)
    attr_auc_max = np.max(time_attr_auc,axis=0)
    attr_auc_min = np.min(time_attr_auc,axis=0)
    edge_auc_mean = np.mean(time_edge_auc,axis=0)
    edge_auc_max = np.max(time_edge_auc,axis=0)
    edge_auc_min = np.min(time_edge_auc,axis=0)

    attr_auc_time.append([attr_auc_mean,attr_auc_min,attr_auc_max])
    edge_auc_time.append([edge_auc_mean,edge_auc_min,edge_auc_max])

    #nll
    attr_nll_mean = np.mean(time_attr_nll,axis=0)
    attr_nll_max = np.max(time_attr_nll,axis=0)
    attr_nll_min = np.min(time_attr_nll,axis=0)
    edge_nll_mean = np.mean(time_edge_nll,axis=0)
    edge_nll_max = np.max(time_edge_nll,axis=0)
    edge_nll_min = np.min(time_edge_nll,axis=0)

    attr_nll_time.append([attr_nll_mean,attr_nll_min,attr_nll_max])
    edge_nll_time.append([edge_nll_mean,edge_nll_min,edge_nll_max])

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 20))


t = [1,2,3,4,5]
colorli = ['red','orange','green','sienna','teal']
titleli = ['edge auc','attr auc','edge nll','attr nll']

for k in range(len(plist)):
    print(edge_auc_time)
    print(edge_nll_time[0][0])
  

#edge auc
#平均
   
    axes[0,0].plot(t, edge_auc_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[0,0].fill_between(t, edge_auc_time[k][1], edge_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[0,1].plot(t, attr_auc_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[0,1].fill_between(t, attr_auc_time[k][1], attr_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[1,0].plot(t, edge_nll_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[1,0].fill_between(t, edge_nll_time[k][1], edge_nll_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション

   


    axes[1,1].plot(t, attr_nll_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[1,1].fill_between(t, attr_nll_time[k][1], attr_nll_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション

   

    axes[0,0].set_xticks([1,2,3,4,5])  
    axes[0,1].set_xticks([1,2,3,4,5])    
    axes[1,0].set_xticks([1,2,3,4,5])
    axes[1,1].set_xticks([1,2,3,4,5])
axes[0,0].plot(t, edge_mean_baseline[0][:], lw=2, label='complete data', color='blue')
axes[0,0].fill_between(t, edge_max_baseline[0][:], edge_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0,1].plot(t, attr_mean_baseline[0][:], lw=2, label='complete data', color='blue')
axes[0,1].fill_between(t, attr_max_baseline[0][:], attr_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1,0].plot(t, edge_mean_nll_baseline[0][:], lw=2, label='complete data', color='blue')
axes[1,0].fill_between(t, edge_max_nll_baseline[0][:], edge_min_nll_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1,1].plot(t, attr_mean_nll_baseline[0][:], lw=2, label='complete data', color='blue')
axes[1,1].fill_between(t, attr_max_nll_baseline[0][:], attr_min_nll_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0,0].set_title(titleli[0])
axes[0,0].legend(loc='upper left')
axes[0,0].set_xlabel('time')
axes[0,0].set_ylabel('accuracy')
axes[0,1].set_title(titleli[1])
axes[0,1].legend(loc='upper left')
axes[0,1].set_xlabel('time')
axes[0,1].set_ylabel('accuracy')
axes[1,0].set_title(titleli[2])
axes[1,0].legend(loc='upper left')
axes[1,0].set_xlabel('time')
axes[1,0].set_ylabel('nll')
axes[1,1].set_title(titleli[3])
axes[1,1].set_title(r'attr nll ')
axes[1,1].legend(loc='upper left')
axes[1,1].set_xlabel('time')
axes[1,1].set_ylabel('nll')
# Out:
# [[array([0.94211118, 0.94588813, 0.9525376 , 0.95565005, 0.84016575]), array([0.9419067 , 0.94366211, 0.94979675, 0.95350881, 0.83538499]), array([0.94268257, 0.94980846, 0.95560976, 0.95821429, 0.84670357])], [array([0.94220008, 0.94615273, 0.95313592, 0.95578309, 0.8406378 ]), array([0.94180972, 0.94201581, 0.95015498, 0.9534833 , 0.83118387]), array([0.94265833, 0.94902531, 0.95722815, 0.9579128 , 0.84396061])], [array([0.94225342, 0.94555628, 0.95264905, 0.95534818, 0.84067877]), array([0.94168849, 0.94103627, 0.94961382, 0.95217764, 0.83637192]), array([0.94317961, 0.94913684, 0.95757876, 0.9605821 , 0.84643683])], [array([0.9420449 , 0.94625618, 0.95234112, 0.95506192, 0.84098337]), array([0.94147027, 0.94395306, 0.94929624, 0.95331633, 0.83654086]), array([0.9426462 , 0.94999758, 0.95504827, 0.9569179 , 0.84536432])], [array([0.94212896, 0.9465123 , 0.9530426 , 0.95624629, 0.83967502]), array([0.94173698, 0.94267287, 0.95003303, 0.95394017, 0.83502823]), array([0.94297352, 0.9
# ...

# %%
attr_auc_time =[]
attr_nll_time = []
edge_auc_time = []
edge_nll_time = []
   
for percent in [5,15,30,50,75]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    for i in range(13,16):

        path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLPP/incomplete/t=4/edge/percent={}/attempt={}".format(percent,i)
        attr_auc_path = path+"/proposed_attr_auc.npy".format(i)
        attr_nll_path = path+"/proposed_attr_nll.npy".format(i)
        edge_auc_path = path+"/proposed_edge_auc.npy".format(i)
        edge_nll_path = path+"/proposed_edge_nll.npy".format(i)

        attr_auc.append(np.load(attr_auc_path))
        attr_nll.append(np.load(attr_nll_path))
        edge_auc.append(np.load(edge_auc_path))
        edge_nll.append(np.load(edge_nll_path))


    #attr_auc_time.append()
    #attr_nll_time = []
    #edge_auc_time = []
    #edge_nll_time = []
    #ある時刻での欠損の位置を変えた時のそれぞれの値
    time_attr_auc = np.mean(attr_auc,axis=1)
    time_edge_auc = np.mean(edge_auc,axis=1)
    time_attr_nll = np.mean(attr_nll,axis=1)
    time_edge_nll = np.mean(edge_nll,axis=1)

    #auc
    attr_auc_mean = np.mean(time_attr_auc,axis=0)
    attr_auc_max = np.max(time_attr_auc,axis=0)
    attr_auc_min = np.min(time_attr_auc,axis=0)
    edge_auc_mean = np.mean(time_edge_auc,axis=0)
    edge_auc_max = np.max(time_edge_auc,axis=0)
    edge_auc_min = np.min(time_edge_auc,axis=0)

    attr_auc_time.append([attr_auc_mean,attr_auc_min,attr_auc_max])
    edge_auc_time.append([edge_auc_mean,edge_auc_min,edge_auc_max])

    #nll
    attr_nll_mean = np.mean(time_attr_nll,axis=0)
    attr_nll_max = np.max(time_attr_nll,axis=0)
    attr_nll_min = np.min(time_attr_nll,axis=0)
    edge_nll_mean = np.mean(time_edge_nll,axis=0)
    edge_nll_max = np.max(time_edge_nll,axis=0)
    edge_nll_min = np.min(time_edge_nll,axis=0)

    attr_nll_time.append([attr_nll_mean,attr_nll_min,attr_nll_max])
    edge_nll_time.append([edge_nll_mean,edge_nll_min,edge_nll_max])

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 20))


t = [1,2,3,4,5]
colorli = ['red','orange','green','sienna','teal']
titleli = ['edge auc','attr auc','edge nll','attr nll']

for k in range(len(plist)):
    print(edge_auc_time)
    print(edge_nll_time[0][0])
  

#edge auc
#平均
   
    axes[0,0].plot(t, edge_auc_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[0,0].fill_between(t, edge_auc_time[k][1], edge_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[0,1].plot(t, attr_auc_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[0,1].fill_between(t, attr_auc_time[k][1], attr_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[1,0].plot(t, edge_nll_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[1,0].fill_between(t, edge_nll_time[k][1], edge_nll_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション

   


    axes[1,1].plot(t, attr_nll_time[k][0], lw=2, label=str(plist[k]), color=colorli[k])
    axes[1,1].fill_between(t, attr_nll_time[k][1], attr_nll_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション

   

    axes[0,0].set_xticks([1,2,3,4,5])  
    axes[0,1].set_xticks([1,2,3,4,5])    
    axes[1,0].set_xticks([1,2,3,4,5])
    axes[1,1].set_xticks([1,2,3,4,5])
axes[0,0].plot(t, edge_mean_baseline[0][:], lw=2, label='complete data', color='blue')
axes[0,0].fill_between(t, edge_max_baseline[0][:], edge_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0,1].plot(t, attr_mean_baseline[0][:], lw=2, label='complete data', color='blue')
axes[0,1].fill_between(t, attr_max_baseline[0][:], attr_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1,0].plot(t, edge_mean_nll_baseline[0][:], lw=2, label='complete data', color='blue')
axes[1,0].fill_between(t, edge_max_nll_baseline[0][:], edge_min_nll_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1,1].plot(t, attr_mean_nll_baseline[0][:], lw=2, label='complete data', color='blue')
axes[1,1].fill_between(t, attr_max_nll_baseline[0][:], attr_min_nll_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0,0].set_title(titleli[0])
axes[0,0].legend(loc='upper left')
axes[0,0].set_xlabel('time')
axes[0,0].set_ylabel('accuracy')
axes[0,1].set_title(titleli[1])
axes[0,1].legend(loc='upper left')
axes[0,1].set_xlabel('time')
axes[0,1].set_ylabel('accuracy')
axes[1,0].set_title(titleli[2])
axes[1,0].legend(loc='upper left')
axes[1,0].set_xlabel('time')
axes[1,0].set_ylabel('nll')
axes[1,1].set_title(titleli[3])
axes[1,1].set_title(r'attr nll ')
axes[1,1].legend(loc='upper left')
axes[1,1].set_xlabel('time')
axes[1,1].set_ylabel('nll')
# Out:
# [[array([0.60643895, 0.54234006, 0.48959607, 0.47769857, 0.48919966]), array([0.5       , 0.5       , 0.46878821, 0.4330957 , 0.46759899]), array([0.81931686, 0.62702017, 0.5       , 0.5       , 0.5       ])], [array([0.72915714, 0.53373526, 0.53427666, 0.62567385, 0.57767799]), array([0.45568843, 0.26775549, 0.30357705, 0.40605663, 0.43472913]), array([0.88555177, 0.84259958, 0.79768996, 0.78613067, 0.79825821])], [array([0.52614233, 0.44816526, 0.4647531 , 0.42397805, 0.42174952]), array([0.48875709, 0.40456819, 0.4357638 , 0.36625897, 0.37427375]), array([0.58966991, 0.5       , 0.5       , 0.5       , 0.5       ])], [array([0.57935296, 0.45132047, 0.47264267, 0.45713466, 0.46514125]), array([0.49988749, 0.3702353 , 0.41906609, 0.3873927 , 0.39692058]), array([0.73617571, 0.49995761, 0.49998614, 0.5       , 0.5       ])], [array([0.59796524, 0.40150168, 0.43081365, 0.41828177, 0.42348676]), array([0.47734115, 0.30608058, 0.31270107, 0.32756451, 0.38104219]), array([0.69818797, 0.5
# ...
