# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cbook as cbook

# %%
fig, ax = plt.subplots(1)
persona = 5



t=0

for p in [4,5,8,12]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    colors = ["yellow","red","green","brown"]

    attr_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_attr_auc.npy".format(p)
    attr_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_attr_nll.npy".format(p)
    edge_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_edge_auc.npy".format(p)
    edge_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_edge_nll.npy".format(p)

    attr_auc.append(np.load(attr_auc_path))
    attr_nll.append(np.load(attr_nll_path))
    edge_auc.append(np.load(edge_auc_path))
    edge_nll.append(np.load(edge_nll_path))

    attr_mean = np.mean(attr_auc,axis=1)
    attr_max = np.max(attr_auc,axis=1)
    attr_min = np.min(attr_auc,axis=1)
    edge_mean = np.mean(edge_auc,axis=1)
    edge_max = np.max(edge_auc,axis=1)
    edge_min = np.min(edge_auc,axis=1)

    time = [1,2,3,4,5]

    ax.plot(time, edge_max[0], lw=2, label=str(p), color=colors[t])
    ax.fill_between(time, edge_min[0], edge_max[0], facecolor=colors[t], alpha=0.1)
    t += 1

attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
p = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32"
attr_auc_path = p+"/proposed_attr_auc.npy".format(persona)
attr_nll_path = p+"/proposed_attr_nll.npy".format(persona)
edge_auc_path = p+"/proposed_edge_auc.npy".format(persona)
edge_nll_path = p+"/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

time = [1,2,3,4,5]

ax.plot(time, edge_max[0], lw=2, label="baseline", color="blue")
#ax.fill_between(time, edge_min[0], edge_max[0], facecolor="blue", alpha=0.1)

ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
persona = 5



t=0

for p in [4,5,8,12]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    colors = ["yellow","red","green","brown"]

    attr_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_attr_auc.npy".format(p)
    attr_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_attr_nll.npy".format(p)
    edge_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_edge_auc.npy".format(p)
    edge_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_edge_nll.npy".format(p)

    attr_auc.append(np.load(attr_auc_path))
    attr_nll.append(np.load(attr_nll_path))
    edge_auc.append(np.load(edge_auc_path))
    edge_nll.append(np.load(edge_nll_path))

    attr_mean = np.mean(attr_nll,axis=1)
    attr_max = np.max(attr_nll,axis=1)
    attr_min = np.min(attr_nll,axis=1)
    edge_mean = np.mean(edge_nll,axis=1)
    edge_max = np.max(edge_nll,axis=1)
    edge_min = np.min(edge_nll,axis=1)

    time = [1,2,3,4,5]

    ax.plot(time, edge_mean[0], lw=2, label=str(p), color=colors[t])
    ax.fill_between(time, edge_min[0], edge_max[0], facecolor=colors[t], alpha=0.1)
    t += 1
    print(attr_mean)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_nll,axis=1)
attr_max = np.max(attr_nll,axis=1)
attr_min = np.min(attr_nll,axis=1)
edge_mean = np.mean(edge_nll,axis=1)
edge_max = np.max(edge_nll,axis=1)
edge_min = np.min(edge_nll,axis=1)

time = [1,2,3,4,5]

ax.plot(time, edge_mean[0], lw=2, label="baseline", color="blue")
ax.fill_between(time, edge_min[0], edge_max[0], facecolor="blue", alpha=0.1)

ax.set_xticks([1,2,3,4,5])
ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# [[6551.43847656 6433.45131836 7333.90322266 7003.2559082  6876.79282227]]
# [[6548.85009766 6432.32724609 7331.8453125  7000.52949219 6873.86826172]]
# [[6552.30566406 6435.51992188 7335.95043945 7006.15009766 6877.77441406]]
# [[6552.90576172 6435.25053711 7335.24624023 7005.78183594 6878.27924805]]
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
persona = 5



t=0

for p in [4,5,8,12]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    colors = ["yellow","red","green","brown"]

    attr_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_attr_auc.npy".format(p)
    attr_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_attr_nll.npy".format(p)
    edge_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_edge_auc.npy".format(p)
    edge_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_edge_nll.npy".format(p)

    attr_auc.append(np.load(attr_auc_path))
    attr_nll.append(np.load(attr_nll_path))
    edge_auc.append(np.load(edge_auc_path))
    edge_nll.append(np.load(edge_nll_path))

    attr_mean = np.mean(attr_auc,axis=1)
    attr_max = np.max(attr_auc,axis=1)
    attr_min = np.min(attr_auc,axis=1)
    edge_mean = np.mean(edge_auc,axis=1)
    edge_max = np.max(edge_auc,axis=1)
    edge_min = np.min(edge_auc,axis=1)

    time = [1,2,3,4,5]

    ax.plot(time, attr_max[0], lw=2, label=str(p), color=colors[t])
    ax.fill_between(time, attr_min[0], attr_max[0], facecolor=colors[t], alpha=0.1)
    t += 1
    print(attr_mean)
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []

p = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32"
attr_auc_path = p+"/proposed_attr_auc.npy".format(persona)
attr_nll_path = p+"/proposed_attr_nll.npy".format(persona)
edge_auc_path = p+"/proposed_edge_auc.npy".format(persona)
edge_nll_path = p+"/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

time = [1,2,3,4,5]

ax.plot(time, attr_mean[0], lw=2, label="baseline", color="blue")
ax.fill_between(time, attr_min[0], attr_max[0], facecolor="blue", alpha=0.1)

ax.set_xticks([1,2,3,4,5])
ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# [[0.74270527 0.74968152 0.70794519 0.71704792 0.71452936]]
# [[0.74278701 0.74894865 0.70774325 0.7178016  0.71556079]]
# [[0.7392359  0.74860443 0.70829794 0.71907716 0.71508871]]
# [[0.74140885 0.75019734 0.70860451 0.71885111 0.71686256]]
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
persona = 5



t=0

for p in [0,0.5,0.75,1.0]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    colors = ["blue","yellow","red","green","brown"]

    attr_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona=5/r={}/proposed_attr_auc.npy".format(p)
    attr_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona=5/r={}/proposed_attr_nll.npy".format(p)
    edge_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona=5/r={}/proposed_edge_auc.npy".format(p)
    edge_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona=5/r={}/proposed_edge_nll.npy".format(p)

    attr_auc.append(np.load(attr_auc_path))
    attr_nll.append(np.load(attr_nll_path))
    edge_auc.append(np.load(edge_auc_path))
    edge_nll.append(np.load(edge_nll_path))

    attr_mean = np.mean(attr_nll,axis=1)
    attr_max = np.max(attr_nll,axis=1)
    attr_min = np.min(attr_nll,axis=1)
    edge_mean = np.mean(edge_nll,axis=1)
    edge_max = np.max(edge_nll,axis=1)
    edge_min = np.min(edge_nll,axis=1)

    time = [1,2,3,4,5]

    ax.plot(time, attr_mean[0], lw=2, label=str(p), color=colors[t])
    ax.fill_between(time, attr_min[0], attr_max[0], facecolor=colors[t], alpha=0.1)
    t += 1
    print(attr_mean)

ax.set_xticks([1,2,3,4,5])
ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# [[6556.00341797 6439.09780273 7339.33647461 7007.91616211 6881.32138672]]
# [[6517.84277344 6389.15161133 7279.22734375 6944.67299805 6810.06152344]]
# [[6551.09667969 6434.24047852 7333.99604492 7004.80883789 6876.50297852]]
# [[6553.85302734 6435.85351562 7336.47939453 7006.59765625 6879.06777344]]
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
persona = 5



t=0

for p in [5,8,12,16,24,32,64,128]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    colors = ["yellow","red","green","brown"]
    attr_auc_path = "experiment_data/DBLP/param/persona={}/proposed_attr_auc.npy".format(p)
    attr_nll_path = "experiment_data/DBLP/param/persona={}/proposed_attr_nll.npy".format(p)
    edge_auc_path = "experiment_data/DBLP/param/persona={}/proposed_edge_auc.npy".format(p)
    edge_nll_path = "experiment_data/DBLP/param/persona={}/proposed_edge_nll.npy".format(p)

    attr_auc.append(np.load(attr_auc_path))
    attr_nll.append(np.load(attr_nll_path))
    edge_auc.append(np.load(edge_auc_path))
    edge_nll.append(np.load(edge_nll_path))

    attr_mean = np.mean(attr_auc,axis=1)
    attr_max = np.max(attr_auc,axis=1)
    attr_min = np.min(attr_auc,axis=1)
    edge_mean = np.mean(edge_auc,axis=1)
    edge_max = np.max(edge_auc,axis=1)
    edge_min = np.min(edge_auc,axis=1)

    time = [1,2,3,4,5]

    ax.plot(time, edge_max[0], lw=2, label=str(p), color=colors[t])
    ax.fill_between(time, edge_min[0], edge_max[0], facecolor=colors[t], alpha=0.1)
    t += 1

attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
p = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32"
attr_auc_path = p+"/proposed_attr_auc.npy".format(persona)
attr_nll_path = p+"/proposed_attr_nll.npy".format(persona)
edge_auc_path = p+"/proposed_edge_auc.npy".format(persona)
edge_nll_path = p+"/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

time = [1,2,3,4,5]

ax.plot(time, edge_max[0], lw=2, label="baseline", color="blue")
#ax.fill_between(time, edge_min[0], edge_max[0], facecolor="blue", alpha=0.1)

ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 21
#      18 edge_auc_path = "coma/experiment_data/DBLP/param/persona={}/proposed_edge_auc.npy".format(p)
#      19 edge_nll_path = "coma/experiment_data/DBLP/param/persona={}/proposed_edge_nll.npy".format(p)
# ---> 21 attr_auc.append(np.load(attr_auc_path))
#      22 attr_nll.append(np.load(attr_nll_path))
#      23 edge_auc.append(np.load(edge_auc_path))
#
# File ~/coma/.venv/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# ...

# %%
fig, ax = plt.subplots(1)
persona = 5



t=0

for p in [5,12,16]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    colors = ["yellow","red","green","brown"]

    attr_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/param/persona={}/proposed_attr_auc.npy".format(p)
    attr_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/param/persona={}/proposed_attr_nll.npy".format(p)
    edge_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/param/persona={}/proposed_edge_auc.npy".format(p)
    edge_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/param/persona={}/proposed_edge_nll.npy".format(p)

    attr_auc.append(np.load(attr_auc_path))
    attr_nll.append(np.load(attr_nll_path))
    edge_auc.append(np.load(edge_auc_path))
    edge_nll.append(np.load(edge_nll_path))

    attr_mean = np.mean(attr_auc,axis=1)
    attr_max = np.max(attr_auc,axis=1)
    attr_min = np.min(attr_auc,axis=1)
    edge_mean = np.mean(edge_auc,axis=1)
    edge_max = np.max(edge_auc,axis=1)
    edge_min = np.min(edge_auc,axis=1)

    time = [1,2,3,4,5]

    ax.plot(time, attr_max[0], lw=2, label=str(p), color=colors[t])
    ax.fill_between(time, attr_min[0], attr_max[0], facecolor=colors[t], alpha=0.1)
    t += 1

attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
p = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32"
attr_auc_path = p+"/proposed_attr_auc.npy".format(persona)
attr_nll_path = p+"/proposed_attr_nll.npy".format(persona)
edge_auc_path = p+"/proposed_edge_auc.npy".format(persona)
edge_nll_path = p+"/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

time = [1,2,3,4,5]

ax.plot(time, attr_max[0], lw=2, label="baseline", color="blue")
#ax.fill_between(time, edge_min[0], edge_max[0], facecolor="blue", alpha=0.1)

ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 4



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)

ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
