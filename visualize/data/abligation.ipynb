# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cbook as cbook

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 4



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')

ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)

ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc (persona={})'.format(persona),fontsize=17)
ax.legend(loc='lower left',fontsize="xx-large")
ax.set_xlabel('time',fontsize=16)
ax.set_ylabel('accuracy',fontsize=16)
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x15834d410>,
#  <matplotlib.axis.XTick at 0x158343550>,
#  <matplotlib.axis.XTick at 0x15833b110>,
#  <matplotlib.axis.XTick at 0x158384d10>,
#  <matplotlib.axis.XTick at 0x158387390>]

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 5



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')

ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)

ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc(persona={})'.format(persona),fontsize=17)
ax.legend(loc='lower left',fontsize="xx-large")
ax.set_xlabel('time',fontsize=16)
ax.set_ylabel('accuracy',fontsize=16)
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x127102610>,
#  <matplotlib.axis.XTick at 0x127106050>,
#  <matplotlib.axis.XTick at 0x127115fd0>,
#  <matplotlib.axis.XTick at 0x127151f90>,
#  <matplotlib.axis.XTick at 0x127158350>]

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 6



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x10d8bf3d0>,
#  <matplotlib.axis.XTick at 0x10d8fb850>,
#  <matplotlib.axis.XTick at 0x10d8fb050>,
#  <matplotlib.axis.XTick at 0x10d94bdd0>,
#  <matplotlib.axis.XTick at 0x10d9522d0>]

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 8



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x10d9ebc50>,
#  <matplotlib.axis.XTick at 0x10da09dd0>,
#  <matplotlib.axis.XTick at 0x10d95fa90>,
#  <matplotlib.axis.XTick at 0x10da46790>,
#  <matplotlib.axis.XTick at 0x10da48b10>]

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 12



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x10d9e3650>,
#  <matplotlib.axis.XTick at 0x10db1b610>,
#  <matplotlib.axis.XTick at 0x10db519d0>,
#  <matplotlib.axis.XTick at 0x10db5bdd0>,
#  <matplotlib.axis.XTick at 0x10db62190>]

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []

for persona in [3,4,5,6,8,12]:
    attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_auc.npy".format(persona)
    attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_attr_nll.npy".format(persona)
    edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_auc.npy".format(persona)
    edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/abligation/persona={}/proposed_edge_nll.npy".format(persona)

    attr_auc.append(np.load(attr_auc_path))
    attr_nll.append(np.load(attr_nll_path))
    edge_auc.append(np.load(edge_auc_path))
    edge_nll.append(np.load(edge_nll_path))


attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='persona3', color='purple')
ax.plot(t, edge_mean[1], lw=2, label='persona4', color='blue')
ax.plot(t, edge_mean[2], lw=2, label='persona5', color='red')
ax.plot(t, edge_mean[3], lw=2, label='persona6', color='orange')
ax.plot(t, edge_mean[4], lw=2, label='persona8', color='green')
ax.plot(t, edge_mean[5], lw=2, label='persona12', color='sienna')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='purple', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[3], edge_max[3], facecolor='orange', alpha=0.1)
ax.fill_between(t, edge_min[4], edge_max[4], facecolor='green', alpha=0.1)
ax.fill_between(t, edge_min[5], edge_max[5], facecolor='sienna', alpha=0.1)


ax.set_title(r'edge')
ax.legend( loc='upper left', bbox_to_anchor=(1, 1),fontsize="xx-large")
ax.tick_params(axis="x", labelsize=16)
ax.tick_params(axis="y", labelsize=16)
ax.set_xlabel('time',fontsize=16)
ax.set_ylabel('auc',fontsize=16)
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x1270b8d90>,
#  <matplotlib.axis.XTick at 0x127bf0890>,
#  <matplotlib.axis.XTick at 0x127bde5d0>,
#  <matplotlib.axis.XTick at 0x127c45890>,
#  <matplotlib.axis.XTick at 0x127c47c10>]

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='persona4', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='persona5', color='red')
ax.plot(t, attr_mean[2], lw=2, label='persona6', color='orange')
ax.plot(t, attr_mean[3], lw=2, label='persona8', color='green')
ax.plot(t, attr_mean[4], lw=2, label='persona12', color='sienna')





ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='orange', alpha=0.1)
ax.fill_between(t, attr_min[3], attr_max[3], facecolor='green', alpha=0.1)
ax.fill_between(t, attr_min[4], attr_max[4], facecolor='sienna', alpha=0.1)



ax.set_title(r'attr')
ax.legend( loc='upper left', bbox_to_anchor=(1, 1),fontsize="xx-large")
ax.tick_params(axis="x", labelsize=16)
ax.tick_params(axis="y", labelsize=16)
ax.set_xlabel('time',fontsize=16)
ax.set_ylabel('auc',fontsize=16)
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x127c71a90>,
#  <matplotlib.axis.XTick at 0x127c87510>,
#  <matplotlib.axis.XTick at 0x127c86bd0>,
#  <matplotlib.axis.XTick at 0x127cdc890>,
#  <matplotlib.axis.XTick at 0x127cded50>]
