# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cbook as cbook

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 4



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x1213094d0>,
#  <matplotlib.axis.XTick at 0x12518b710>,
#  <matplotlib.axis.XTick at 0x1251e6790>,
#  <matplotlib.axis.XTick at 0x125247dd0>,
#  <matplotlib.axis.XTick at 0x12524dcd0>]

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 5



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x125300ad0>,
#  <matplotlib.axis.XTick at 0x1252f6c50>,
#  <matplotlib.axis.XTick at 0x1252e6590>,
#  <matplotlib.axis.XTick at 0x12533f950>,
#  <matplotlib.axis.XTick at 0x125345c50>]

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 6



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x1254034d0>,
#  <matplotlib.axis.XTick at 0x1254013d0>,
#  <matplotlib.axis.XTick at 0x1253e9c50>,
#  <matplotlib.axis.XTick at 0x12543e490>,
#  <matplotlib.axis.XTick at 0x12543c710>]

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 8



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x1254e0550>,
#  <matplotlib.axis.XTick at 0x1255026d0>,
#  <matplotlib.axis.XTick at 0x1254f1c50>,
#  <matplotlib.axis.XTick at 0x12553fdd0>,
#  <matplotlib.axis.XTick at 0x12520ad50>]

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []
persona = 16



attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/200_20/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/k-mean/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_auc.npy".format(persona)
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_attr_nll.npy".format(persona)
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_auc.npy".format(persona)
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/abligation/persona={}/proposed_edge_nll.npy".format(persona)

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, edge_mean[2], lw=2, label='abligation', color='green')





ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='green', alpha=0.1)


ax.set_xticks([1,2,3,4,5])
ax.set_title(r'edge auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='proposed', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='k-mean', color='red')
ax.plot(t, attr_mean[2], lw=2, label='abligation', color='green')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='green', alpha=0.1)

ax.set_title(r'attr auc persona={}'.format(persona))
ax.legend(loc='upper left')
ax.set_xlabel('time')
ax.set_ylabel('accuracy')
ax.set_xticks([1,2,3,4,5])
# Out:
# [<matplotlib.axis.XTick at 0x1263b1050>,
#  <matplotlib.axis.XTick at 0x1263aaf10>,
#  <matplotlib.axis.XTick at 0x125266590>,
#  <matplotlib.axis.XTick at 0x1263ef8d0>,
#  <matplotlib.axis.XTick at 0x1263f1bd0>]
