# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cbook as cbook
import japanize_matplotlib

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []




attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32/proposed_attr_auc.npy"
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32/proposed_attr_nll.npy"
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32/proposed_edge_auc.npy"
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32/proposed_edge_nll.npy"

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

for i in [5,12,24]:
    attr_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/param/persona={}/proposed_attr_auc.npy".format(i)
    attr_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/param/persona={}/proposed_attr_nll.npy".format(i)
    edge_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/param/persona={}/proposed_edge_auc.npy".format(i)
    edge_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/DBLP/param/persona={}/proposed_edge_nll.npy".format(i)

    attr_auc.append(np.load(attr_auc_path))
    attr_nll.append(np.load(attr_nll_path))
    edge_auc.append(np.load(edge_auc_path))
    edge_nll.append(np.load(edge_nll_path))


attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='Baseline', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='Persona5', color='red')
ax.plot(t, edge_mean[2], lw=2, label='Persona12', color='orange')
ax.plot(t, edge_mean[3], lw=2, label='Persona23', color='green')
#ax.plot(t, edge_mean[4], lw=2, label='Persona8', color='sienna')
#ax.plot(t, edge_mean[5], lw=2, label='Persona16', color='teal')
#ax.plot(t, edge_mean[5], lw=2, label='Persona32', color='purple')




ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='orange', alpha=0.1)
ax.fill_between(t, edge_min[3], edge_max[3], facecolor='green', alpha=0.1)
#ax.fill_between(t, edge_min[4], edge_max[4], facecolor='sienna', alpha=0.1)
#ax.fill_between(t, edge_min[5], edge_max[5], facecolor='teal', alpha=0.1)
#ax.fill_between(t, edge_min[5], edge_max[6], facecolor='purple', alpha=0.1)

ax.set_title(r'エッジ',fontsize=30)
ax.legend( loc='upper left', bbox_to_anchor=(1, 1),fontsize=30)
ax.set_xlabel('将来の時刻',fontsize=30)
ax.set_ylabel('auc',fontsize=30)
ax.tick_params(axis="x", labelsize=30)
ax.tick_params(axis="y", labelsize=30)
ax.set_xticks([1,2,3,4,5])

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='Baseline', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='Persona5', color='red')
ax.plot(t, attr_mean[2], lw=2, label='Persona12', color='orange')
ax.plot(t, attr_mean[3], lw=2, label='Persona24', color='green')
#ax.plot(t, attr_mean[4], lw=2, label='Persona8', color='sienna')
#ax.plot(t, attr_mean[5], lw=2, label='Persona16', color='teal')
#ax.plot(t, attr_mean[6], lw=2, label='Persona32', color='purple')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='orange', alpha=0.1)
ax.fill_between(t, attr_min[3], attr_max[3], facecolor='green', alpha=0.1)
#ax.fill_between(t, attr_min[4], attr_max[4], facecolor='sienna', alpha=0.1)
#ax.fill_between(t, attr_min[5], attr_max[5], facecolor='teal', alpha=0.1)
#ax.fill_between(t, attr_min[6], attr_max[6], facecolor='purple', alpha=0.1)

ax.set_title(r'属性値',fontsize=30)
ax.legend( loc='upper left', bbox_to_anchor=(1, 1),fontsize=30)
ax.set_xlabel('将来の時刻',fontsize=30)
ax.set_ylabel('auc',fontsize=30)
ax.tick_params(axis="x", labelsize=30)
ax.tick_params(axis="y", labelsize=30)
ax.set_xticks([1,2,3,4,5])

# %%
attr_auc = []
attr_nll = []
edge_auc = []
edge_nll = []




attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32/proposed_attr_auc.npy"
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32/proposed_attr_nll.npy"
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32/proposed_edge_auc.npy"
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32/proposed_edge_nll.npy"

attr_auc.append(np.load(attr_auc_path))
attr_nll.append(np.load(attr_nll_path))
edge_auc.append(np.load(edge_auc_path))
edge_nll.append(np.load(edge_nll_path))

for i in [3,4,5,6,8,12,16]:
    attr_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_attr_auc.npy".format(i)
    attr_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_attr_nll.npy".format(i)
    edge_auc_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_edge_auc.npy".format(i)
    edge_nll_path = "/Users/matsumoto-hirotomo/coma/experiment_data/NIPS/param/persona={}/proposed_edge_nll.npy".format(i)

    attr_auc.append(np.load(attr_auc_path))
    attr_nll.append(np.load(attr_nll_path))
    edge_auc.append(np.load(edge_auc_path))
    edge_nll.append(np.load(edge_nll_path))


attr_mean = np.mean(attr_auc,axis=1)
attr_max = np.max(attr_auc,axis=1)
attr_min = np.min(attr_auc,axis=1)
edge_mean = np.mean(edge_auc,axis=1)
edge_max = np.max(edge_auc,axis=1)
edge_min = np.min(edge_auc,axis=1)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
t = [1,2,3,4,5]
ax.plot(t, attr_mean[0], lw=2, label='Baseline', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='Persona3', color='red')
ax.plot(t, attr_mean[2], lw=2, label='Persona4', color='orange')
ax.plot(t, attr_mean[3], lw=2, label='Persona5', color='green')
ax.plot(t, attr_mean[4], lw=2, label='Persona6', color='sienna')
ax.plot(t, attr_mean[5], lw=2, label='Persona8', color='teal')
ax.plot(t, attr_mean[6], lw=2, label='Persona12', color='purple')




ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='orange', alpha=0.1)
ax.fill_between(t, attr_min[3], attr_max[3], facecolor='green', alpha=0.1)
ax.fill_between(t, attr_min[4], attr_max[4], facecolor='sienna', alpha=0.1)
ax.fill_between(t, attr_min[5], attr_max[5], facecolor='teal', alpha=0.1)
ax.fill_between(t, attr_min[6], attr_max[6], facecolor='purple', alpha=0.1)

ax.set_title(r'属性値',fontsize=30)
ax.legend( loc='upper left', bbox_to_anchor=(1, 1),fontsize=30)
ax.set_xlabel('将来の時刻',fontsize=30)
ax.set_ylabel('auc',fontsize=30)
ax.tick_params(axis="x", labelsize=30)
ax.tick_params(axis="y", labelsize=30)
ax.set_xticks([1,2,3,4,5])

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='Baseline', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='Persona3', color='red')
ax.plot(t, edge_mean[2], lw=2, label='Persona4', color='orange')
ax.plot(t, edge_mean[3], lw=2, label='Persona5', color='green')
ax.plot(t, edge_mean[4], lw=2, label='Persona6', color='sienna')
ax.plot(t, edge_mean[5], lw=2, label='Persona8', color='teal')
ax.plot(t, edge_mean[5], lw=2, label='Persona12', color='purple')




ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='orange', alpha=0.1)
ax.fill_between(t, edge_min[3], edge_max[3], facecolor='green', alpha=0.1)
ax.fill_between(t, edge_min[4], edge_max[4], facecolor='sienna', alpha=0.1)
ax.fill_between(t, edge_min[5], edge_max[5], facecolor='teal', alpha=0.1)
ax.fill_between(t, edge_min[5], edge_max[6], facecolor='purple', alpha=0.1)

ax.set_title(r'エッジ',fontsize=30)
ax.legend( loc='upper left', bbox_to_anchor=(1, 1),fontsize=30)
ax.set_xlabel('将来の時刻',fontsize=30)
ax.set_ylabel('auc',fontsize=30)
ax.tick_params(axis="x", labelsize=30)
ax.tick_params(axis="y", labelsize=30)
ax.set_xticks([1,2,3,4,5])

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, edge_mean[0], lw=2, label='NIPS32', color='blue')
ax.plot(t, edge_mean[1], lw=2, label='DBLP32', color='red')
ax.plot(t, edge_mean[2], lw=2, label='NIPS64', color='orange')
ax.plot(t, edge_mean[3], lw=2, label='DBLP64', color='green')
#ax.plot(t, edge_mean[4], lw=2, label='persona16', color='sienna')
#ax.plot(t, edge_mean[5], lw=2, label='persona32', color='teal')
#ax.plot(t, edge_mean[6], lw=2, label='persona16', color='indigo')

ax.fill_between(t, edge_min[0], edge_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, edge_min[1], edge_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, edge_min[2], edge_max[2], facecolor='orange', alpha=0.1)
ax.fill_between(t, edge_min[3], edge_max[3], facecolor='green', alpha=0.1)
#ax.fill_between(t, edge_min[4], edge_max[4], facecolor='sienna', alpha=0.1)
#ax.fill_between(t, edge_min[5], edge_max[5], facecolor='teal', alpha=0.1)
#ax.fill_between(t, edge_min[6], edge_max[6], facecolor='indigo', alpha=0.1)

ax.set_title(r'edge auc')
ax.legend(loc='upper left')
ax.set_xlabel('num steps')
ax.set_ylabel('position')
# Out:
# Text(0, 0.5, 'position')

# %%
fig, ax = plt.subplots(1)
t = [1,2,3,4,5]

ax.plot(t, attr_mean[0], lw=2, label='NIPS32', color='blue')
ax.plot(t, attr_mean[1], lw=2, label='DBLP32', color='red')
ax.plot(t, attr_mean[2], lw=2, label='NIPS64', color='orange')
ax.plot(t, attr_mean[3], lw=2, label='DBLP64', color='green')
#ax.plot(t, edge_mean[4], lw=2, label='persona16', color='sienna')
#ax.plot(t, edge_mean[5], lw=2, label='persona32', color='teal')
#ax.plot(t, edge_mean[6], lw=2, label='persona16', color='indigo')

ax.fill_between(t, attr_min[0], attr_max[0], facecolor='blue', alpha=0.1)
ax.fill_between(t, attr_min[1], attr_max[1], facecolor='red', alpha=0.1)
ax.fill_between(t, attr_min[2], attr_max[2], facecolor='orange', alpha=0.1)
ax.fill_between(t, attr_min[3], attr_max[3], facecolor='green', alpha=0.1)
#ax.fill_between(t, edge_min[4], edge_max[4], facecolor='sienna', alpha=0.1)
#ax.fill_between(t, edge_min[5], edge_max[5], facecolor='teal', alpha=0.1)
#ax.fill_between(t, edge_min[6], edge_max[6], facecolor='indigo', alpha=0.1)

ax.set_title(r'edge auc')
ax.legend(loc='upper left')
ax.set_xlabel('num steps')
ax.set_ylabel('position')
# Out:
# Text(0, 0.5, 'position')
