# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

# %%
for p in [4,5,8,12,16]:
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
    print("persona:",p)
    print("T",param[:p])
    print("e",param[p:2*p])
    print("r",param[2*p:3*p])
    print("w",param[3*p:4*p])
    print("-------------------")
# Out:
# persona: 4
# T [1.6755928 1.4670678 1.5975121 1.5315769]
# e [1.0441296 0.8942239 0.9844693 1.0513322]
# r [0.61654603 1.0624754  0.5879212  0.9975402 ]
# w [0.8959081  0.791982   0.91892046 0.80408865]
# -------------------
# persona: 5
# T [1.5584224 1.70947   1.7201575 1.5962993 1.7138972]
# e [0.97447366 0.9650238  0.8959241  0.9453804  0.8845112 ]
# r [0.5546276  0.872993   0.95486957 0.8241953  0.69963557]
# w [0.87633854 0.7898493  0.94125277 0.9260473  0.7543304 ]
# -------------------
# persona: 8
# T [1.7256427 1.5709434 1.6821675 1.8980474 1.8409655 1.6865582 1.7413031
#  1.663282 ]
# e [0.9309841  1.0152631  1.0775579  0.95395297 1.0737578  0.76654226
#  1.1379608  0.640514  ]
# r [0.7899073  0.81030124 0.79861987 0.7478308  0.7751002  0.7533178
#  0.7483136  0.797405  ]
# w [0.8434365  0.8753157  0.99398714 0.945137   0.93952936 0.9530116
#  0.848043   0.8588513 ]
# -------------------
# persona: 12
# T [1.5790734 1.8281637 1.8116378 1.805093  1.7896601 1.4784479 1.8115873
#  1.6809825 1.5258647 1.9399513 1.796691  1.7029694]
# e [1.1539676 1.0140681 1.1371688 0.9548042 0.9610106 1.0360891 0.8451509
#  1.0452682 0.9171973 1.0202256 0.8994394 1.0630108]
# r [0.69587725 0.966867   0.959194   0.90709513 0.7028248  0.51481795
#  0.853387   0.8045156  0.65570813 0.8443026  0.7874326  0.90607905]
# w [1.0404433  0.87387043 0.9018263  1.1060156  0.83170325 1.0370859
#  0.8919014  1.0457721  0.9019398  0.8741405  1.0358604  0.96583223]
# -------------------
# persona: 16
# T [1.296049  1.7237054 1.8709874 1.803402  1.6841061 1.8073038 1.7585237
#  1.3563437 1.778889  1.7933854 1.6669335 1.7495141 1.8113049 1.8841071
#  1.8839763 1.8273901]
# e [1.1605844  1.1201694  0.76110214 1.0432808  1.0026256  0.9391497
#  1.0008346  1.0960913  1.0866469  1.1034913  1.0403868  0.83310544
#  1.1141472  0.9555835  1.2554796  1.0660155 ]
# r [0.5438554  0.8181056  0.90359914 0.83940333 0.81987536 0.9525838
#  0.805204   0.5378035  0.86392343 0.8084685  0.8660045  0.7333432
#  0.7283106  0.7497869  0.7686441  0.9486064 ]
# w [0.9044522  0.82762617 0.9117375  0.86312217 0.7756844  0.86655504
#  0.93576825 0.92040735 0.93077594 0.8038593  0.79024565 0.9984435
#  0.7831858  0.87840366 0.8546095  0.8794059 ]
# -------------------

# %%
for p in [4,5,8,12,16]:
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
    print("persona:",p)
    print("T",param[:p])
    print("e",param[p:2*p])
    print("r",param[2*p:3*p])
    print("w",param[3*p:4*p])
    print("-------------------")
# Out:
# persona: 4
# T [1.6755928 1.4670678 1.5975121 1.5315769]
# e [1.0441296 0.8942239 0.9844693 1.0513322]
# r [0.61654603 1.0624754  0.5879212  0.9975402 ]
# w [0.8959081  0.791982   0.91892046 0.80408865]
# -------------------
# persona: 5
# T [1.5584224 1.70947   1.7201575 1.5962993 1.7138972]
# e [0.97447366 0.9650238  0.8959241  0.9453804  0.8845112 ]
# r [0.5546276  0.872993   0.95486957 0.8241953  0.69963557]
# w [0.87633854 0.7898493  0.94125277 0.9260473  0.7543304 ]
# -------------------
# persona: 8
# T [1.7256427 1.5709434 1.6821675 1.8980474 1.8409655 1.6865582 1.7413031
#  1.663282 ]
# e [0.9309841  1.0152631  1.0775579  0.95395297 1.0737578  0.76654226
#  1.1379608  0.640514  ]
# r [0.7899073  0.81030124 0.79861987 0.7478308  0.7751002  0.7533178
#  0.7483136  0.797405  ]
# w [0.8434365  0.8753157  0.99398714 0.945137   0.93952936 0.9530116
#  0.848043   0.8588513 ]
# -------------------
# persona: 12
# T [1.5790734 1.8281637 1.8116378 1.805093  1.7896601 1.4784479 1.8115873
#  1.6809825 1.5258647 1.9399513 1.796691  1.7029694]
# e [1.1539676 1.0140681 1.1371688 0.9548042 0.9610106 1.0360891 0.8451509
#  1.0452682 0.9171973 1.0202256 0.8994394 1.0630108]
# r [0.69587725 0.966867   0.959194   0.90709513 0.7028248  0.51481795
#  0.853387   0.8045156  0.65570813 0.8443026  0.7874326  0.90607905]
# w [1.0404433  0.87387043 0.9018263  1.1060156  0.83170325 1.0370859
#  0.8919014  1.0457721  0.9019398  0.8741405  1.0358604  0.96583223]
# -------------------
# persona: 16
# T [1.296049  1.7237054 1.8709874 1.803402  1.6841061 1.8073038 1.7585237
#  1.3563437 1.778889  1.7933854 1.6669335 1.7495141 1.8113049 1.8841071
#  1.8839763 1.8273901]
# e [1.1605844  1.1201694  0.76110214 1.0432808  1.0026256  0.9391497
#  1.0008346  1.0960913  1.0866469  1.1034913  1.0403868  0.83310544
#  1.1141472  0.9555835  1.2554796  1.0660155 ]
# r [0.5438554  0.8181056  0.90359914 0.83940333 0.81987536 0.9525838
#  0.805204   0.5378035  0.86392343 0.8084685  0.8660045  0.7333432
#  0.7283106  0.7497869  0.7686441  0.9486064 ]
# w [0.9044522  0.82762617 0.9117375  0.86312217 0.7756844  0.86655504
#  0.93576825 0.92040735 0.93077594 0.8038593  0.79024565 0.9984435
#  0.7831858  0.87840366 0.8546095  0.8794059 ]
# -------------------

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [4,5,8,12,16]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[:p],param[p:2*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 4
# persona: 5
# persona: 8
# persona: 12
# persona: 16

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [4,5,8,12,16]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[3*p:4*p],param[2*p:3*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 4
# persona: 5
# persona: 8
# persona: 12
# persona: 16

# %% [markdown]
# T::エッジの貼りやすさ(繋がりやすい)
# 大
# e:エッジの貼りやすさ(繋がりやすい)
# 小
# →右下ほど他と繋がりやすい
# →左上ほど他と繋がりにくい
# r:影響力
# 大　影響力ある
# w:属性値の維持(頑固さ)

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [4,5,8,12,16]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/DBLP/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[:p],param[p:2*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 7
#       5 p = p_num[c]
#       6 parameter_path =  "experiment_data/DBLP/param/persona={}/paramerter.npy".format(p)
# ----> 7 param = np.load(parameter_path)
#      10 ax.scatter(param[:p],param[p:2*p], lw=2, label='persona{}'.format(p), color=colors[c])
#      11 print("persona:",p)
#
# File ~/coma/.venv/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiment_data/DBLP/param/persona=4/paramerter.npy'

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [5,6,8,12]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/DBLP/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[3*p:4*p],param[2*p:3*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 5
# persona: 6
# persona: 8
# persona: 12
