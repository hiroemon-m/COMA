# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

# %%
for p in [3,4,5,6,8,12,16]:
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
    print("persona:",p)
    print("T",param[:p])
    print("e",param[p:2*p])
    print("r",param[2*p:3*p])
    print("w",param[3*p:4*p])
    print("-------------------")
# Out:
# persona: 3
# T [0.2999996  0.30805254 0.30640882]
# e [0.58097553 1.2661521  1.424499  ]
# r [1.6892313 1.7001309 1.6170346]
# w [0.608059  0.617393  0.6064328]
# -------------------
# persona: 4
# T [0.18328533 0.25559494 0.19719796 0.22069617]
# e [1.0948428  1.1487806  0.60563624 1.2401363 ]
# r [1.1474929  0.97551084 1.1742793  1.1559465 ]
# w [0.6128315  0.88716584 0.601323   0.37776873]
# -------------------
# persona: 5
# T [0.1495064  0.19592118 0.16838008 0.19670309 0.19047116]
# e [0.91584694 1.234877   0.8754811  0.86439186 0.49344873]
# r [1.1870053 1.2570156 1.2100048 1.3047051 1.3030784]
# w [0.9089493 0.4001047 0.8357494 0.519113  0.6612193]
# -------------------
# persona: 6
# T [0.22841401 0.21960211 0.15206297 0.22816844 0.25827083 0.23550992]
# e [0.63817173 0.98272914 1.0131993  1.1187304  0.9302072  1.0969775 ]
# r [1.6616094 1.649917  1.3410084 1.6067047 1.7736715 1.69331  ]
# w [0.58930105 0.5775454  0.96026754 0.6049709  0.54947764 0.59583277]
# ...

# %%
for p in [3,4,5,6,8,12,16]:
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
    print("persona:",p)
    print("T",param[:p])
    print("e",param[p:2*p])
    print("r",param[2*p:3*p])
    print("w",param[3*p:4*p])
    print("-------------------")

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [3,4,5,6,8,12,16]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[:p],param[p:2*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 3
# persona: 4
# persona: 5
# persona: 6
# persona: 8
# persona: 12
# persona: 16

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [3,4,5,6,8,12,16]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[3*p:4*p],param[2*p:3*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 3
# persona: 4
# persona: 5
# persona: 6
# persona: 8
# persona: 12
# persona: 16

# %% [markdown]
# T::エッジの貼りやすさ(繋がりやすい)
# 大
# e:エッジの貼りやすさ(繋がりやすい)
# 小
# →右下ほど他と繋がりやすい
# →左上ほど他と繋がりにくい
# r:影響力
# 大　影響力ある
# w:属性値の維持(頑固さ)

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [5,6,8,12]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/DBLP/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[:p],param[p:2*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 5
# persona: 6
# persona: 8
# persona: 12

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [5,6,8,12]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/DBLP/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[3*p:4*p],param[2*p:3*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 5
# persona: 6
# persona: 8
# persona: 12
